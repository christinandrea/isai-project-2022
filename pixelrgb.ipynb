# %% [markdown]
# <a href="https://colab.research.google.com/github/christinandrea/isai-project-2022/blob/v1-ml/pixelrgb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
path = 'sample_data/dog1.jpg'
img = cv.imread(path, cv.IMREAD_UNCHANGED)

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
img[10,10]
# Out:
# array([195, 210, 226], dtype=uint8)

# %%
b,g,r=img[10,10]
print(b,g,r)
# Out:
# 195 210 226

# %%
img[105,150]
# Out:
# array([193, 208, 227], dtype=uint8)

# %%
b,g,r=img[105,150]
print(b,g,r)
# Out:
# 193 208 227

# %% [markdown]
# - entah gimana caranya buat nampung nilai pixel dari koordinat di imagenya, maybe array/dict
# - pixel terjemahin ke nilai rgb
# - habis itu nilai rgbnya diproses dst dst
